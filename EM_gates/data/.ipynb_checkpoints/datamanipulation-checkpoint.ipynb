# %%
#Read dataframes
import pandas as pd
subcategorydf = pd.read_csv('subcategoryold.csv')

# %%
subdomaindf = pd.read_csv('subdomains.csv')

# %%
subcategorydf
# Out:
#                             "Sub Domain"  \
# 0                         School Climate
# 1                         School Climate
# 2                         School Climate
# 3                         School Climate
# 4                         School Climate
# 5                         School Climate
# 6                         School Climate
# 7              Early Childhood Education
# 8              Early Childhood Education
# 9              Early Childhood Education
# 10             Early Childhood Education
# 11             Early Childhood Education
# 12             Early Childhood Education
# 13   Post-Secondary Affordability Policy
# 14   Post-Secondary Affordability Policy
# 15  Post- Secondary Affordability Policy
# 16          Workforce Development Policy
# 17          Workforce Development Policy
# 18          Workforce Development Policy
#
#                                      "Sub Categories"    Oregon  Virginia  \
# ...

# %%
subdomaindf_melt = subdomaindf.melt(id_vars =['"Sub Domains"'], var_name = "State", value_name = "Score")

# %%
subdomaindf_melt
# Out:
#                    "Sub Domains"     State     Score
# 0                 School Climate    Oregon  0.839286
# 1      Early Childhood Education    Oregon  0.640000
# 2   Post-Secondary Affordability    Oregon  0.888889
# 3   Workforce Development Policy    Oregon  0.472222
# 4                 School Climate  Virginia  0.848810
# 5      Early Childhood Education  Virginia  0.640000
# 6   Post-Secondary Affordability  Virginia  0.666667
# 7   Workforce Development Policy  Virginia  0.833333
# 8                 School Climate      Iowa  0.372109
# 9      Early Childhood Education      Iowa  0.640000
# 10  Post-Secondary Affordability      Iowa  0.888889
# 11  Workforce Development Policy      Iowa  0.638889

# %%
#mlet dataframes for the right way to get graphs easily
subdomaindf = subdomaindf_melt.to_csv('/sfs/qumulo/qhome/mc9bn/git/dspg20uvaEM/EM_gates/data/subdomain.csv')

# %%
subcategorydf_melt = subcategorydf.melt(id_vars =['"Sub Domain"','"Sub Categories"'], var_name = "State", value_name = "Score")

# %%
subcategorydf_melt
# Out:
#                             "Sub Domain"  \
# 0                         School Climate
# 1                         School Climate
# 2                         School Climate
# 3                         School Climate
# 4                         School Climate
# 5                         School Climate
# 6                         School Climate
# 7              Early Childhood Education
# 8              Early Childhood Education
# 9              Early Childhood Education
# 10             Early Childhood Education
# 11             Early Childhood Education
# 12             Early Childhood Education
# 13   Post-Secondary Affordability Policy
# 14   Post-Secondary Affordability Policy
# 15  Post- Secondary Affordability Policy
# 16          Workforce Development Policy
# 17          Workforce Development Policy
# 18          Workforce Development Policy
# 19                        School Climate
# 20                        School Climate
# 21                        School Climate
# ...

# %%
subcategorydf = subcategorydf_melt.to_csv('/sfs/qumulo/qhome/mc9bn/git/dspg20uvaEM/EM_gates/data/subcategory.csv')

# %%
subdomaindf_melt
# Out:
#                    "Sub Domains"     State     Score
# 0                 School Climate    Oregon  0.839286
# 1      Early Childhood Education    Oregon  0.640000
# 2   Post-Secondary Affordability    Oregon  0.888889
# 3   Workforce Development Policy    Oregon  0.472222
# 4                 School Climate  Virginia  0.848810
# 5      Early Childhood Education  Virginia  0.640000
# 6   Post-Secondary Affordability  Virginia  0.666667
# 7   Workforce Development Policy  Virginia  0.833333
# 8                 School Climate      Iowa  0.372109
# 9      Early Childhood Education      Iowa  0.640000
# 10  Post-Secondary Affordability      Iowa  0.888889
# 11  Workforce Development Policy      Iowa  0.638889

# %%
subcategorydf_melt
# Out:
#                             "Sub Domain"  \
# 0                         School Climate
# 1                         School Climate
# 2                         School Climate
# 3                         School Climate
# 4                         School Climate
# 5                         School Climate
# 6                         School Climate
# 7              Early Childhood Education
# 8              Early Childhood Education
# 9              Early Childhood Education
# 10             Early Childhood Education
# 11             Early Childhood Education
# 12             Early Childhood Education
# 13   Post-Secondary Affordability Policy
# 14   Post-Secondary Affordability Policy
# 15  Post- Secondary Affordability Policy
# 16          Workforce Development Policy
# 17          Workforce Development Policy
# 18          Workforce Development Policy
# 19                        School Climate
# 20                        School Climate
# 21                        School Climate
# ...
